# %%
import pandas as pd

# %%
WHEELS = [
    {   
        'wheel_id': 'w1',
        'lost': 1,
        'loose': 2,
        'broken': 3,
    },
    {   
        'wheel_id': 'w2',
        'lost': 1,
        'loose': 2,
        'broken': 3,
    },
    {
        'wheel_id': 'w3',
        'lost': 1,
        'loose': 2,
        'broken': 3,
    },
    {
        'wheel_id': 'w4',
        'lost': 1,
        'loose': 2,
        'broken': 3,
    }
]

# %%
df = pd.DataFrame(WHEELS)
df.set_index('wheel_id', inplace=True)
df
# Out:
#           lost  loose  broken
# wheel_id
# w1           1      2       3
# w2           1      2       3
# w3           1      2       3
# w4           1      2       3

# %%
df['anormal'] = 0
df
# Out:
#           lost  loose  broken  anormal
# wheel_id
# w1           1      2       3        0
# w2           1      2       3        0
# w3           1      2       3        0
# w4           1      2       3        0

# %%
df.loc['w1', 'broken']
# Out:
# 3
